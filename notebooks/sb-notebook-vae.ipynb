# %% [markdown]
# # VAE Attempt

# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# %%
ds = image_dataset_from_directory('/home/jupyter/data_local', label_mode=None, image_size=(448, 448))
# Out:
# Found 2360 files belonging to 1 classes.

# %%
##ds = ds.map(lambda x: x/255)
##ds = ds.map(lambda x: (x, x))

# %%
imgs = ds.as_numpy_iterator().__next__()

# %%
imgs.shape
# Out:
# (32, 448, 448, 3)

# %%
plt.imshow(imgs[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, LeakyReLU

X_train=imgs/255

def build_encoder(latent_dimension):
    encoder = Sequential()
    
    encoder.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(448, 448, 3)))
    encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))
    
    encoder.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU()))
    encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Flatten())
    encoder.add(Dense(latent_dimension, activation='tanh'))
    
    return encoder

# %%
encoder = build_encoder(latent_dimension=20)

# %%
from tensorflow.keras.layers import Reshape, Conv2DTranspose
def build_decoder(latent_dimension):
    decoder = Sequential()
    decoder.add(Dense(7*7*64, activation='tanh', input_shape=(latent_dimension,)))
    decoder.add(Reshape((7, 7, 64)))
    decoder.add(Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(16, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(8, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid'))
    return decoder

# %%
encoder.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_75 (Conv2D)          (None, 448, 448, 32)      896
#
#  batch_normalization_60 (Bat  (None, 448, 448, 32)     128
#  chNormalization)
#
#  max_pooling2d_75 (MaxPoolin  (None, 224, 224, 32)     0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 224, 224, 64)      18496
#
#  batch_normalization_61 (Bat  (None, 224, 224, 64)     256
#  chNormalization)
#
#  max_pooling2d_76 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_77 (Conv2D)          (None, 112, 112, 128)     73856
#
#  batch_normalization_62 (Bat  (None, 112, 112, 128)    512
#  chNormalization)
#
#  max_pooling2d_77 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 56, 56, 256)       295168
#
#  batch_normalization_63 (Bat  (None, 56, 56, 256)      1024
#  chNormalization)
#
#  max_pooling2d_78 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 200704)            0
#
#  dense_42 (Dense)            (None, 128)               25690240
#
# =================================================================
# Total params: 26,080,576
# Trainable params: 26,079,616
# Non-trainable params: 960
# _________________________________________________________________

# %%
decoder = build_decoder(20)

# %%
decoder.summary()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_43 (Dense)            (None, 3136)              404544
#
#  reshape_23 (Reshape)        (None, 7, 7, 64)          0
#
#  conv2d_transpose_99 (Conv2D  (None, 14, 14, 128)      73856
#  Transpose)
#
#  conv2d_transpose_100 (Conv2  (None, 28, 28, 64)       73792
#  DTranspose)
#
#  conv2d_transpose_101 (Conv2  (None, 56, 56, 32)       18464
#  DTranspose)
#
#  conv2d_transpose_102 (Conv2  (None, 112, 112, 16)     4624
#  DTranspose)
#
#  conv2d_transpose_103 (Conv2  (None, 224, 224, 8)      1160
#  DTranspose)
#
#  conv2d_transpose_104 (Conv2  (None, 448, 448, 3)      219
#  DTranspose)
#
# =================================================================
# Total params: 576,659
# Trainable params: 576,659
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
def build_autoencoder(encoder, decoder):
    inp = Input((448, 448, 3))
    encoded = encoder(inp)
    decoded = decoder(encoded)
    autoencoder = Model(inp, decoded)
    return autoencoder

autoencoder = build_autoencoder(encoder, decoder)

# %%
def compile_autoencoder(autoencoder):
    autoencoder.compile(loss='mse', optimizer='adam')

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='loss', patience=10)

compile_autoencoder(autoencoder)
autoencoder.fit(X_train, X_train, epochs=1000, batch_size=32, callbacks=[es], verbose=1)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.0114
# Epoch 2/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0117
# Epoch 3/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0118
# Epoch 4/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0116
# Epoch 5/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0115
# Epoch 6/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0115
# Epoch 7/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0115
# Epoch 8/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0114
# Epoch 9/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0114
# Epoch 10/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0114
# Epoch 11/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0114
# Epoch 12/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0114
# Epoch 13/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0114
# Epoch 14/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0114
# Epoch 15/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0113
# Epoch 16/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0113
# Epoch 17/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0113
# Epoch 18/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0113
# Epoch 19/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0113
# Epoch 20/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0113
# Epoch 21/1000
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0112
# Epoch 22/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0112
# Epoch 23/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0112
# Epoch 24/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0112
# Epoch 25/1000
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0112
# Epoch 26/1000
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0112
# Epoch 27/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0112
# Epoch 28/1000
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0112
# Epoch 29/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0111
# Epoch 30/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0111
# Epoch 31/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0111
# Epoch 32/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0111
# Epoch 33/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0111
# Epoch 34/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0111
# Epoch 35/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0111
# Epoch 36/1000
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0111
# Epoch 37/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0111
# Epoch 38/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0111
# Epoch 39/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0110
# Epoch 40/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0110
# Epoch 41/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 0.0110
# Epoch 42/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0110
# Epoch 43/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0110
# Epoch 44/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0109
# Epoch 45/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0109
# Epoch 46/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0109
# Epoch 47/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0109
# Epoch 48/1000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0109
# Epoch 49/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0109
# Epoch 50/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0109
# Epoch 51/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0109
# Epoch 52/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 53/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 54/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 55/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 56/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 57/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0108
# Epoch 58/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0107
# Epoch 59/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0107
# Epoch 60/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0107
# Epoch 61/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0107
# Epoch 62/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0106
# Epoch 63/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 0.0107
# Epoch 64/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0106
# Epoch 65/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0106
# Epoch 66/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0106
# Epoch 67/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0106
# Epoch 68/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0106
# Epoch 69/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0105
# Epoch 70/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0105
# Epoch 71/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0105
# Epoch 72/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0105
# Epoch 73/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0105
# Epoch 74/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0105
# Epoch 75/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0104
# Epoch 76/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0104
# Epoch 77/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0104
# Epoch 78/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0104
# Epoch 79/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0104
# Epoch 80/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0104
# Epoch 81/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0103
# Epoch 82/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0103
# Epoch 83/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0103
# Epoch 84/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0103
# Epoch 85/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0103
# Epoch 86/1000
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0103
# Epoch 87/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0104
# Epoch 88/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0104
# Epoch 89/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0102
# Epoch 90/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0102
# Epoch 91/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0103
# Epoch 92/1000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0102
# Epoch 93/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0102
# Epoch 94/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0102
# Epoch 95/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0101
# Epoch 96/1000
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0101
# Epoch 97/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0102
# Epoch 98/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0101
# Epoch 99/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0101
# Epoch 100/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0101
# Epoch 101/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0100
# Epoch 102/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0100
# Epoch 103/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0100
# Epoch 104/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0100
# Epoch 105/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0100
# Epoch 106/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0100
# Epoch 107/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0100
# Epoch 108/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0099
# Epoch 109/1000
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0099
# Epoch 110/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0099
# Epoch 111/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0099
# Epoch 112/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0099
# Epoch 113/1000
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0099
# Epoch 114/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0099
# Epoch 115/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0099
# Epoch 116/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0098
# Epoch 117/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0098
# Epoch 118/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0098
# Epoch 119/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0098
# Epoch 120/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0098
# Epoch 121/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0098
# Epoch 122/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0098
# Epoch 123/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0098
# Epoch 124/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0097
# Epoch 125/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0097
# Epoch 126/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0097
# Epoch 127/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0097
# Epoch 128/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0097
# Epoch 129/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0097
# Epoch 130/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0097
# Epoch 131/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0097
# Epoch 132/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0097
# Epoch 133/1000
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0096
# Epoch 134/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0096
# Epoch 135/1000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0096
# Epoch 136/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0096
# Epoch 137/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0096
# Epoch 138/1000
# 1/1 [==============================] - 0s 352ms/step - loss: 0.0096
# Epoch 139/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0096
# Epoch 140/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0096
# Epoch 141/1000
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0096
# Epoch 142/1000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0096
# Epoch 143/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0096
# Epoch 144/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0097
# Epoch 145/1000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0098
# Epoch 146/1000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0100
# Epoch 147/1000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0096
# Epoch 148/1000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0097
# Epoch 149/1000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0098
# Epoch 150/1000
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0096
# Epoch 151/1000
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0097
# Epoch 152/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0097

# %%
prediction = autoencoder.predict(X_train, verbose=0, batch_size=32)# you can now display an image to see it is reconstructed well

# %%
prediction.shape
# Out:
# (32, 448, 448, 3)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((prediction[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(448, 448, 3))
    plt.show()
