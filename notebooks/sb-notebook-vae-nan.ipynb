# %% [markdown]
# # Functional API & Latent Space

# %%
import os
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, LeakyReLU
from tensorflow.keras.layers import Reshape, Conv2DTranspose, UpSampling2D
from tensorflow.keras import Model
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# %%
ds = image_dataset_from_directory('/home/jupyter/data_local', label_mode=None, image_size=(448, 448), batch_size=None)
# Out:
# Found 2360 files belonging to 1 classes.
# 2023-03-09 17:22:29.996456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.008984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.010728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.013647: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-09 17:22:30.014403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.016192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.017889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.701019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.702877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.704546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-09 17:22:30.706129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13598 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
##ds = ds.map(lambda x: x/255)
##ds = ds.map(lambda x: (x, x))

# %%
imgs = ds.as_numpy_iterator().__next__()

# %%
imgs.shape
# Out:
# (448, 448, 3)

# %%
plt.imshow(imgs)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X_train = ds.map(lambda x : x/255).batch(16).prefetch(tf.data.AUTOTUNE)

# %%
from keras.layers import Lambda

# %%
from keras.models import Model
from keras.losses import binary_crossentropy
from keras.layers import Layer

# %%
import tensorflow as tf
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 800


input_image = Input(shape=(448, 448, 3))
    
x = Conv2D(32, (3, 3), padding='same', activation=LeakyReLU())(input_image)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), padding='same', activation=LeakyReLU())(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), padding='same', activation=LeakyReLU())(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(256, (3, 3), padding='same', activation=LeakyReLU())(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
encoder_output = Dense(latent_dim, activation='tanh')(x)

z_mean = tf.keras.layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = tf.keras.layers.Dense(latent_dim, name="z_log_var")(x)

z = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model(input_image, [z_mean, z_log_var, z], name="encoder")

encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 448, 448, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 448, 448, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 448, 448, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 224, 224, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 64  0          ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 128)  0          ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['batch_normalization_3[0][0]']
#
#  flatten (Flatten)              (None, 200704)       0           ['max_pooling2d_3[0][0]']
#
#  z_mean (Dense)                 (None, 800)          160564000   ['flatten[0][0]']
#
#  z_log_var (Dense)              (None, 800)          160564000   ['flatten[0][0]']
#
#  sampling (Sampling)            (None, 800)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 321,518,336
# Trainable params: 321,517,376
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
latent_inputs = tf.keras.Input(shape=(latent_dim,))  
x = Dense(7*7*64, activation='tanh')(latent_inputs)
x = Reshape((7, 7, 64))(x)
x = Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation=LeakyReLU(alpha=0.001))(x)
x = Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation=LeakyReLU(alpha=0.001))(x)
x = Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation=LeakyReLU(alpha=0.001))(x)
x = Conv2DTranspose(16, (3, 3), strides=2, padding='same', activation=LeakyReLU(alpha=0.001))(x)
x = Conv2DTranspose(8, (3, 3), strides=2, padding='same', activation=LeakyReLU(alpha=0.001))(x)
    
decoder_output = Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid')(x)
    
decoder = Model(inputs=latent_inputs, outputs=decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 800)]             0
#
#  dense_1 (Dense)             (None, 3136)              2511936
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      73856
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       73792
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 56, 56, 32)       18464
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 112, 112, 16)     4624
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 224, 224, 8)      1160
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 448, 448, 3)      219
#  ranspose)
#
# =================================================================
# Total params: 2,684,051
# Trainable params: 2,684,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
X_train
# Out:
# <PrefetchDataset element_spec=TensorSpec(shape=(None, 448, 448, 3), dtype=tf.float32, name=None)>

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=tf.keras.optimizers.Adam())
vae.fit(X_train, epochs=100)
# Out:
# Epoch 1/100
# 2023-03-09 17:22:52.624310: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 148/148 [==============================] - 44s 249ms/step - loss: nan - reconstruction_loss: nan - kl_loss: nan
# Epoch 2/100
# 148/148 [==============================] - 37s 239ms/step - loss: nan - reconstruction_loss: nan - kl_loss: nan
# Epoch 3/100
# 115/148 [======================>.......] - ETA: 7s - loss: nan - reconstruction_loss: nan - kl_loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/tmp/ipykernel_16986/981066457.py in <module>
#       1 vae = VAE(encoder, decoder)
#       2 vae.compile(optimizer=tf.keras.optimizers.Adam())
# ----> 3 vae.fit(X_train, epochs=100)
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /opt/conda/lib/python3.7/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
final_decoder = vae.decoder

# %%
latent_space = np.random.rand(50,1)

# %%
encoded_image = vae.encoder(imgs[5].reshape(-1,448,448,3))
decoded_image = vae.decoder(encoded_image[0])
plt.imshow((decoded_image.numpy().reshape(448,448,3) * 255).astype(np.uint8))

# %%
plt.imshow((final_decoder(latent_space * 255).numpy().reshape(448,448,3).astype(np.uint8))

# %%
#encoder = build_encoder(latent_dimension=800)

# %%
#decoder = build_decoder(latent_dimension=800)

# %%
encoder.summary()

# %%
decoder.summary()

# %%
def build_autoencoder(encoder, decoder):
    inp = Input((448, 448, 3))
    encoded = encoder(inp)
    decoded = decoder(encoded)
    autoencoder = Model(inp, decoded)
    return autoencoder

autoencoder = build_autoencoder(encoder, decoder)

# %%
def compile_autoencoder(autoencoder):
    autoencoder.compile(loss='mse', optimizer='adam')

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)

compile_autoencoder(autoencoder)
autoencoder.fit(X_train, X_train, epochs=1000, batch_size=32, callbacks=[es], verbose=1)

# %%
prediction = autoencoder.predict(X_train, verbose=0, batch_size=32)# you can now display an image to see it is reconstructed well

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((prediction[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(448, 448, 3))
    plt.show()

# %%
#autoencoder.save('autoencoder-latent-dim-800.h5')

# %%
# !pip install opencv-python

# %%
import cv2
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter('video.mp4', fourcc, 25.0, (448, 448))

for i in range(len(prediction)):
    image = prediction[i]
    image= cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    video_writer.write(image)
    
video_writer.release()
prediction = (prediction * 255).astype(np.uint8)

fps = 2
out = cv2.VideoWriter('output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (prediction.shape[2], prediction.shape[1]))
for i in range(aj.shape[0]):
    data = prediction[i, :, :, :]
    data = cv2.cvtColor(data, cv2.COLOR_RGB2BGR)
    out.write(data)
out.release()

# %%
n = 20  # figure with 20x20 samples
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

# Construct grid of latent variable values - can change values here to generate different things
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

# decode for each square in the grid
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        z_sample = np.tile(z_sample, batch_size).reshape(batch_size, 2)
        
        x_decoded = decoder.predict(z_sample, batch_size=batch_size)
        
        digit = x_decoded[0].reshape(digit_size, digit_size)
        
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(20, 20))
plt.imshow(figure)
plt.show()
