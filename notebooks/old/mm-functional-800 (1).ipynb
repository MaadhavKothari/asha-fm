# %% [markdown]
# # SETUP

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import tensorflow as tf

from tensorflow.keras.utils import image_dataset_from_directory

# %%
ds = tf.keras.utils.image_dataset_from_directory("zelle", label_mode=None, image_size=(448, 448), batch_size=16)

# %%
imgs = ds.as_numpy_iterator().__next__()

# %%
plt.imshow((imgs[0]).astype(np.uint8))

# %%
X_train = imgs/255

# %% [markdown]
# # BUILD ENCODER

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, LeakyReLU


from tensorflow.keras import Model
from tensorflow.keras.layers import Input

def build_encoder(latent_dimension):
    
    input_image=Input(shape=(448,448,3))

    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_image)
    x = MaxPooling2D(2)(x)
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D(2)(x)
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D(2)(x)
    x = Conv2D(256, (3, 3), padding='same', activation=LeakyReLU())(x)
    x= BatchNormalization()(x)
    x = MaxPooling2D(2)(x)
           
    x = Flatten()(x)
    encoder_output=Dense(latent_dimension, activation='relu')(x)
           
    encoder = Model(inputs=input_image, outputs=encoder_output)

    return encoder

# %%
encoder = build_encoder(latent_dimension=800)

# %%
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 448, 448, 3)]     0
#
#  conv2d (Conv2D)             (None, 448, 448, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 224, 224, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  max_pooling2d_2 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 256)       295168
#
#  batch_normalization (BatchN  (None, 56, 56, 256)      1024
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 200704)            0
#
#  dense (Dense)               (None, 800)               160564000
#
# =================================================================
# Total params: 160,953,440
# Trainable params: 160,952,928
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# # BUILD DECODER

# %%
from tensorflow.keras.layers import Reshape, Conv2DTranspose, UpSampling2D
def build_decoder(latent_dimension):
    
    latent_space_input=Input(shape=latent_dimension)

    x=Dense(7*7*64, activation='tanh')(latent_space_input)
    x=Reshape((7, 7, 64))(x)
    x=Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation='relu')(x)
    x=Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
    x=Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation='relu')(x)
    x=Conv2DTranspose(16, (3, 3), strides=2, padding='same', activation='relu')(x)
    x=Conv2DTranspose(8, (3, 3), strides=2, padding='same', activation='relu')(x)

    decoder_output=Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid')(x)
    
    decoder = Model(inputs=latent_space_input, outputs=decoder_output)
    
    return decoder

# %%
decoder = build_decoder(800)
decoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 800)]             0
#
#  dense_2 (Dense)             (None, 3136)              2511936
#
#  reshape_1 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_6 (Conv2DT  (None, 14, 14, 128)      73856
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 28, 28, 64)       73792
#  ranspose)
#
#  conv2d_transpose_8 (Conv2DT  (None, 56, 56, 32)       18464
#  ranspose)
#
#  conv2d_transpose_9 (Conv2DT  (None, 112, 112, 16)     4624
#  ranspose)
#
#  conv2d_transpose_10 (Conv2D  (None, 224, 224, 8)      1160
#  Transpose)
#
#  conv2d_transpose_11 (Conv2D  (None, 448, 448, 3)      219
#  Transpose)
#
# =================================================================
# Total params: 2,684,051
# Trainable params: 2,684,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # BUILD AUTOENCODER

# %%
def build_autoencoder(encoder, decoder):
    inp = Input((448, 448, 3))
    encoded = encoder(inp)
    decoded = decoder(encoded)
    autoencoder = Model(inp, decoded)
    return autoencoder

autoencoder = build_autoencoder(encoder, decoder)

# %%
autoencoder = build_autoencoder(encoder, decoder)

# %%
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 448, 448, 3)]     0
#
#  model (Functional)          (None, 800)               160953440
#
#  model_4 (Functional)        (None, 448, 448, 3)       2684051
#
# =================================================================
# Total params: 163,637,491
# Trainable params: 163,636,979
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# # COMPILE AUTOENCODER

# %%
def compile_autoencoder(autoencoder):
    autoencoder.compile(loss='mse', optimizer='adam')

# %% [markdown]
# # RUN AUTOENCODER

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

compile_autoencoder(autoencoder)

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, callbacks=[es], verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2282
# Epoch 2/100
# 1/1 [==============================] - 1s 642ms/step - loss: 0.2278
# Epoch 3/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.2273
# Epoch 4/100
# 1/1 [==============================] - 1s 636ms/step - loss: 0.2268
# Epoch 5/100
# 1/1 [==============================] - 1s 645ms/step - loss: 0.2261
# Epoch 6/100
# 1/1 [==============================] - 1s 640ms/step - loss: 0.2252
# Epoch 7/100
# 1/1 [==============================] - 1s 731ms/step - loss: 0.2241
# Epoch 8/100
# 1/1 [==============================] - 1s 654ms/step - loss: 0.2225
# Epoch 9/100
# 1/1 [==============================] - 1s 640ms/step - loss: 0.2202
# Epoch 10/100
# 1/1 [==============================] - 1s 642ms/step - loss: 0.2170
# Epoch 11/100
# 1/1 [==============================] - 1s 625ms/step - loss: 0.2124
# Epoch 12/100
# 1/1 [==============================] - 1s 625ms/step - loss: 0.2060
# Epoch 13/100
# 1/1 [==============================] - 1s 625ms/step - loss: 0.1976
# Epoch 14/100
# 1/1 [==============================] - 1s 629ms/step - loss: 0.1871
# Epoch 15/100
# 1/1 [==============================] - 1s 638ms/step - loss: 0.1752
# Epoch 16/100
# 1/1 [==============================] - 1s 624ms/step - loss: 0.1636
# Epoch 17/100
# 1/1 [==============================] - 1s 639ms/step - loss: 0.1535
# Epoch 18/100
# 1/1 [==============================] - 1s 634ms/step - loss: 0.1448
# Epoch 19/100
# 1/1 [==============================] - 1s 626ms/step - loss: 0.1364
# Epoch 20/100
# 1/1 [==============================] - 1s 629ms/step - loss: 0.1279
# Epoch 21/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.1193
# Epoch 22/100
# 1/1 [==============================] - 1s 649ms/step - loss: 0.1108
# Epoch 23/100
# 1/1 [==============================] - 1s 647ms/step - loss: 0.1029
# Epoch 24/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0953
# Epoch 25/100
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0881
# Epoch 26/100
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0809
# Epoch 27/100
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0740
# Epoch 28/100
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0680
# Epoch 29/100
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0632
# Epoch 30/100
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0595
# Epoch 31/100
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0563
# Epoch 32/100
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0539
# Epoch 33/100
# 1/1 [==============================] - 1s 666ms/step - loss: 0.0526
# Epoch 34/100
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0517
# Epoch 35/100
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0507
# Epoch 36/100
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0495
# Epoch 37/100
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0484
# Epoch 38/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0477
# Epoch 39/100
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0474
# Epoch 40/100
# 1/1 [==============================] - 1s 629ms/step - loss: 0.0473
# Epoch 41/100
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0472
# Epoch 42/100
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0471
# Epoch 43/100
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0469
# Epoch 44/100
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0465
# Epoch 45/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0459
# Epoch 46/100
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0449
# Epoch 47/100
# 1/1 [==============================] - 1s 630ms/step - loss: 0.0439
# Epoch 48/100
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0427
# Epoch 49/100
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0415
# Epoch 50/100
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0404
# Epoch 51/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0388
# Epoch 52/100
# 1/1 [==============================] - 1s 630ms/step - loss: 0.0366
# Epoch 53/100
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0345
# Epoch 54/100
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0332
# Epoch 55/100
# 1/1 [==============================] - 1s 692ms/step - loss: 0.0323
# Epoch 56/100
# 1/1 [==============================] - 1s 746ms/step - loss: 0.0312
# Epoch 57/100
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0294
# Epoch 58/100
# 1/1 [==============================] - 1s 711ms/step - loss: 0.0282
# Epoch 59/100
# 1/1 [==============================] - 1s 714ms/step - loss: 0.0280
# Epoch 60/100
# 1/1 [==============================] - 1s 758ms/step - loss: 0.0280
# Epoch 61/100
# 1/1 [==============================] - 1s 773ms/step - loss: 0.0279
# Epoch 62/100
# 1/1 [==============================] - 1s 762ms/step - loss: 0.0279
# Epoch 63/100
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0279
# Epoch 64/100
# 1/1 [==============================] - 1s 754ms/step - loss: 0.0278
# Epoch 65/100
# 1/1 [==============================] - 1s 740ms/step - loss: 0.0278
# Epoch 66/100
# 1/1 [==============================] - 1s 752ms/step - loss: 0.0277
# Epoch 67/100
# 1/1 [==============================] - 1s 718ms/step - loss: 0.0277
# Epoch 68/100
# 1/1 [==============================] - 1s 776ms/step - loss: 0.0276
# Epoch 69/100
# 1/1 [==============================] - 1s 776ms/step - loss: 0.0275
# Epoch 70/100
# 1/1 [==============================] - 1s 763ms/step - loss: 0.0275
# Epoch 71/100
# 1/1 [==============================] - 1s 761ms/step - loss: 0.0274
# Epoch 72/100
# 1/1 [==============================] - 1s 766ms/step - loss: 0.0274
# Epoch 73/100
# 1/1 [==============================] - 1s 758ms/step - loss: 0.0273
# Epoch 74/100
# 1/1 [==============================] - 1s 687ms/step - loss: 0.0273
# Epoch 75/100
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0272
# Epoch 76/100
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0271
# Epoch 77/100
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0270
# Epoch 78/100
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0270
# Epoch 79/100
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0269
# Epoch 80/100
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0268
# Epoch 81/100
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0268
# Epoch 82/100
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0267
# Epoch 83/100
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0266
# Epoch 84/100
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0265
# Epoch 85/100
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0265
# Epoch 86/100
# 1/1 [==============================] - 1s 625ms/step - loss: 0.0264
# Epoch 87/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0263
# Epoch 88/100
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0263
# Epoch 89/100
# 1/1 [==============================] - 1s 625ms/step - loss: 0.0263
# Epoch 90/100
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0262
# Epoch 91/100
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0261
# Epoch 92/100
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0260
# Epoch 93/100
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0259
# Epoch 94/100
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0259
# Epoch 95/100
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0258
# Epoch 96/100
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0257
# Epoch 97/100
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0256
# Epoch 98/100
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0255
# Epoch 99/100
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0254
# Epoch 100/100
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0254

# %%
prediction=autoencoder.predict(X_train, verbose=0, batch_size = 32)

# %%
prediction.shape
# Out:
# (16, 448, 448, 3)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((prediction[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(448, 448, 3))
    plt.show()

# %% [markdown]
# # LATENT SPACE

# %%
latent_space = encoder.predict(X_train)
# Out:
# 1/1 [==============================] - 0s 112ms/step

# %%
from tensorflow.keras.models import load_model
from tensorflow.random import normal
from tensorflow.math import exp
from tensorflow import shape

# %%
latent_dimension=800

# %%
autoencoder_model = autoencoder

latent_space_input=Input(shape=latent_dimension)

x=Dense(7*7*64, activation='tanh')(latent_space_input)
x=Reshape((7, 7, 64))(x)
x=Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation='relu')(x)
x=Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu')(x)
x=Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation='relu')(x)
x=Conv2DTranspose(256, (3, 3), strides=2, padding='same', activation='relu')(x)
x=Conv2DTranspose(8, (3, 3), strides=2, padding='same', activation='relu')(x)


##decoder_output=Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid')(x)

decoder_output=Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid')(x)
    
##decoder = Model(inputs=latent_space_input, outputs=decoder_output)

decoder = Model(inputs=latent_space_input, outputs=decoder_output)

# Generate output from a given z vector
latent_dimension=800
z_mu = Dense(latent_dimension)(latent_space_input)
z_log_sigma = Dense(latent_dimension)(latent_space_input)
epsilon = normal(shape(z_mu))
z = z_mu + exp(z_log_sigma / 2) * epsilon

# %%
z_decoded = decoder(z)
z_decoded
# Out:
# <KerasTensor: shape=(None, 448, 448, 3) dtype=float32 (created by layer 'model_12')>

# %%
from tensorflow.keras.backend import backend as K
from tensorflow.keras import layers
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.layers import Lambda

# %%
class CustomVariationalLayer(Layer):

    def vae_loss(self, x, z_decoded):
        x = K.flatten(x)
        z_decoded = K.flatten(z_decoded)
        # Reconstruction loss
        xent_loss = binary_crossentropy(x, z_decoded)
        # KL divergence
        kl_loss = -5e-4 * K.mean(1 + z_log_sigma - K.square(z_mu) - K.exp(z_log_sigma), axis=-1)
        return K.mean(xent_loss + kl_loss)

    # adds the custom loss to the class
    def call(self, inputs):
        x = inputs[0]
        z_decoded = inputs[1]
        loss = self.vae_loss(x, z_decoded)
        self.add_loss(loss, inputs=inputs)
        return x

# apply the custom loss to the input images and the decoded latent distribution sample
y = CustomVariationalLayer()([latent_space_input, z_decoded])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1/1328048206.py in <module>
# ----> 1 class CustomVariationalLayer(Layer):
#       2
#       3     def vae_loss(self, x, z_decoded):
#       4         x = K.flatten(x)
#       5         z_decoded = K.flatten(z_decoded)
#
# NameError: name 'Layer' is not defined

# %%
# VAE model statement
vae = Model(input_img, y)
vae.compile(optimizer='rmsprop', loss=None)

vae.fit(x=train_x, y=None,
        shuffle=True,
        epochs=20,
        batch_size=batch_size,
        validation_data=(val_x, None))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1/2869493293.py in <module>
#       1 # VAE model statement
# ----> 2 vae = Model(input_img, y)
#       3 vae.compile(optimizer='rmsprop', loss=None)
#       4
#       5 vae.fit(x=train_x, y=None,
#
# NameError: name 'input_img' is not defined

# %%
something=z_decoded*prediction
something
# Out:
# <KerasTensor: shape=(16, 448, 448, 3) dtype=float32 (created by layer 'tf.math.multiply_2')>

# %%
autoencoder_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 448, 448, 3)]     0
#
#  model (Functional)          (None, 800)               160953440
#
#  model_1 (Functional)        (None, 448, 448, 3)       2684051
#
# =================================================================
# Total params: 163,637,491
# Trainable params: 163,636,979
# Non-trainable params: 512
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 800)]             0
#
#  dense_7 (Dense)             (None, 3136)              2511936
#
#  reshape_2 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_12 (Conv2D  (None, 14, 14, 128)      73856
#  Transpose)
#
#  conv2d_transpose_13 (Conv2D  (None, 28, 28, 64)       73792
#  Transpose)
#
#  conv2d_transpose_14 (Conv2D  (None, 56, 56, 32)       18464
#  Transpose)
#
#  conv2d_transpose_15 (Conv2D  (None, 112, 112, 16)     4624
#  Transpose)
#
#  conv2d_transpose_16 (Conv2D  (None, 224, 224, 8)      1160
#  Transpose)
#
#  conv2d_transpose_17 (Conv2D  (None, 448, 448, 3)      219
#  Transpose)
#
# =================================================================
# Total params: 2,684,051
# Trainable params: 2,684,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.compat.v1.enable_eager_execution()

# %%
something_array=something.eval()

# %%
my_array = something.numpy()

# Plot the image using matplotlib
plt.imshow(my_array)
plt.show()

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(something, show_shapes=True)

# %%
decoder(np.ones(800).reshape(-1,800))

# %%
from tensorflow.math import square
from tensorflow.math import reduce_mean
from tensorflow.keras.losses import MeanSquaredError

# %%
def vae_loss(inputs, outputs, z_mean, z_log_var):
    # Compute reconstruction loss
    reconstruction_loss = MeanSquaredError(inputs, outputs)
    reconstruction_loss *= 448 * 448 * 3  # Scale up to match size of inputs
    
    # Compute KL divergence loss
    kl_loss = 1 + z_log_var - square(z_mean) - exp(z_log_var)
    kl_loss = reduce_mean(kl_loss, axis=-1)
    kl_loss *= -0.5
    
    # Combine losses
    total_loss = reduce_mean(reconstruction_loss + kl_loss)
    return total_loss

# %%
autoencoder_model.compile(optimizer='adam', run_eagerly = True, loss=lambda prediction,  z_decoded: vae_loss(X_train,z_decoded, z_mu, z_log_sigma))

# %%
z_model=autoencoder_model.fit(X_train,  y=None, epochs = 200, batch_size = 32, callbacks=[es], validation_data=(X_train, None))

# %% [markdown]
# # ADDING NOISE

# %%
noise_factor = 0.1

X_train_noisy = X_train + noise_factor * np.random.normal(0., 1., size=X_train.shape)

# %%
noisy=autoencoder.fit(X_train_noisy, X_train, epochs = 10000, batch_size = 32, callbacks=[es])

# %%
noisyprediction=autoencoder.predict(X_train, verbose=0, batch_size = 32)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((noisyprediction[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(108, 144, 3))
    plt.show()

# %%
noise_factor2 = 0.5

X_train_noisy2 = X_train + noise_factor2 * np.random.normal(0., 1., size=X_train.shape)

# %%
noisy2=autoencoder.fit(X_train_noisy2, X_train, epochs = 20000, batch_size = 32, callbacks=[es])

# %%
noisyprediction2=autoencoder.predict(X_train_noisy2, verbose=0, batch_size = 32)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((noisyprediction2[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(108, 144, 3))
    plt.show()

# %%
noise_factor3 = 1

X_train_noisy3 = X_train + noise_factor3 * np.random.normal(0., 1., size=X_train.shape)

# %%
noisy3=autoencoder.fit(X_train_noisy3, X_train, epochs = 20000, batch_size = 32, callbacks=[es])

# %%
noisyprediction3=autoencoder.predict(X_train_noisy3, verbose=0, batch_size = 32)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((noisyprediction3[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(108, 144, 3))
    plt.show()

# %%
noise_factor4 = 2

X_train_noisy4 = X_train + noise_factor4 * np.random.normal(0., 1., size=X_train.shape)

# %%
noisy4=autoencoder.fit(X_train_noisy4, X_train, epochs = 20000, batch_size = 32, callbacks=[es])

# %%
noisyprediction4=autoencoder.predict(X_train_noisy4, verbose=0, batch_size = 32)

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((noisyprediction4[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(108, 144, 3))
    plt.show()
