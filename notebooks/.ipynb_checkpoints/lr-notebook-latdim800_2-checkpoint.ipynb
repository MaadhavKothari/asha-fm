# %% [markdown]
# # VAE Attempt

# %%
import os
import matplotlib.image as pltim
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Rescaling
# Out:
# 2023-03-09 23:34:26.820912: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-09 23:34:26.899849: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-09 23:34:26.903540: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-09 23:34:26.903550: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-09 23:34:26.920387: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-09 23:34:27.311073: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-09 23:34:27.311105: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-09 23:34:27.311108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Params

BATCH_SIZE = 32
INPUT_SHAPE = (448, 448, 3)
EPOCHS = 500

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# %%
X_train = image_dataset_from_directory(
    '../raw_data/abstract_art_512/', 
    labels=None, # Changed from label_mode -> labels
    image_size=INPUT_SHAPE[:2], 
    batch_size=BATCH_SIZE,
    crop_to_aspect_ratio=True,
)
# Out:
# Found 8145 files belonging to 1 classes.
# 2023-03-09 23:34:28.125776: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-09 23:34:28.125795: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-09 23:34:28.125808: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lscr): /proc/driver/nvidia/version does not exist
# 2023-03-09 23:34:28.126008: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##ds = ds.map(lambda x: x/255)
##ds = ds.map(lambda x: (x, x))

# %%
im = Image.open('../raw_data/abstract_art_512/abstract_abdul-qader-al-raes_258.jpg')
im.mode
# Out:
# 'RGB'

# %%
im = pltim.imread('../raw_data/abstract_art_512/abstract_abdul-qader-al-raes_258.jpg')
plt.imshow(im)

# %%
imgs = X_train.as_numpy_iterator().__next__()

# %%
imgs.shape
# Out:
# (32, 448, 448, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, LeakyReLU

X_train=imgs/255

def build_encoder(latent_dimension):
    encoder = Sequential()
    
    encoder.add(Rescaling(scale=1./255, input_shape=(448, 448, 3))) # Added this layer
    encoder.add(Conv2D(32, (3, 3), padding='same', activation='relu')) #, input_shape=(448, 448, 3)))
    # encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    # encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    # encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))
    
    encoder.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU()))
    # encoder.add(BatchNormalization())
    encoder.add(MaxPooling2D((2, 2)))

    encoder.add(Flatten())
    encoder.add(Dense(latent_dimension, activation='tanh'))
    
    return encoder

# %%
from tensorflow.keras.layers import Reshape, Conv2DTranspose, UpSampling2D
def build_decoder(latent_dimension):
    decoder = Sequential()
    decoder.add(Dense(7*7*64, activation='tanh', input_shape=(latent_dimension,)))
    decoder.add(Reshape((7, 7, 64)))
    decoder.add(Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation='relu'))
    #decoder.add(UpSampling2D((2, 2)))
    decoder.add(Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(16, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(8, (3, 3), strides=2, padding='same', activation='relu'))
    decoder.add(Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid'))
    return decoder

# %%
encoder = build_encoder(latent_dimension=800)

# %%
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 448, 448, 3)       0
#
#  conv2d (Conv2D)             (None, 448, 448, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 224, 224, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  max_pooling2d_2 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 200704)            0
#
#  dense (Dense)               (None, 800)               160564000
#
# =================================================================
# Total params: 160,952,416
# Trainable params: 160,952,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder = build_decoder(latent_dimension=800)

# %%
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 3136)              2511936
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      73856
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       73792
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 56, 56, 32)       18464
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 112, 112, 16)     4624
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 224, 224, 8)      1160
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 448, 448, 3)      219
#  ranspose)
#
# =================================================================
# Total params: 2,684,051
# Trainable params: 2,684,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input
def build_autoencoder(encoder, decoder):
    inp = Input(INPUT_SHAPE)
    encoded = encoder(inp)
    decoded = decoder(encoded)
    autoencoder = Model(inp, decoded)
    return autoencoder

autoencoder = build_autoencoder(encoder, decoder)

# %%
def compile_autoencoder(autoencoder):
    autoencoder.compile(loss='mse', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)

compile_autoencoder(autoencoder)
autoencoder.fit(
    X_train, X_train, 
    epochs=1000, 
    batch_size=BATCH_SIZE, 
    callbacks=[es], 
    verbose=1
)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0944
# Epoch 2/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0944
# Epoch 3/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0943
# Epoch 4/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0943
# Epoch 5/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0943
# Epoch 6/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0942
# Epoch 7/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0942
# Epoch 8/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0942
# Epoch 9/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0941
# Epoch 10/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0941
# Epoch 11/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0941
# Epoch 12/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0940
# Epoch 13/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0940
# Epoch 14/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0939
# Epoch 15/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0939
# Epoch 16/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0939
# Epoch 17/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0938
# Epoch 18/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0938
# Epoch 19/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0937
# Epoch 20/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0937
# Epoch 21/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0936
# Epoch 22/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0936
# Epoch 23/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0935
# Epoch 24/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0935
# Epoch 25/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0934
# Epoch 26/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0934
# Epoch 27/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0933
# Epoch 28/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0933
# Epoch 29/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0932
# Epoch 30/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0931
# Epoch 31/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0930
# Epoch 32/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0930
# Epoch 33/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0929
# Epoch 34/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0928
# Epoch 35/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0927
# Epoch 36/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0926
# Epoch 37/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0925
# Epoch 38/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0924
# Epoch 39/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0923
# Epoch 40/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0922
# Epoch 41/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0921
# Epoch 42/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0920
# Epoch 43/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0919
# Epoch 44/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0919
# Epoch 45/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0918
# Epoch 46/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0918
# Epoch 47/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0918
# Epoch 48/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0917
# Epoch 49/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0917
# Epoch 50/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0916
# Epoch 51/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0915
# Epoch 52/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0914
# Epoch 53/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0914
# Epoch 54/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0913
# Epoch 55/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0913
# Epoch 56/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0912
# Epoch 57/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0911
# Epoch 58/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0910
# Epoch 59/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0910
# Epoch 60/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0909
# Epoch 61/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0909
# Epoch 62/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0908
# Epoch 63/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0907
# Epoch 64/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0907
# Epoch 65/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0906
# Epoch 66/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0906
# Epoch 67/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0905
# Epoch 68/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0905
# Epoch 69/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0904
# Epoch 70/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0904
# Epoch 71/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0904
# Epoch 72/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0903
# Epoch 73/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0903
# Epoch 74/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0902
# Epoch 75/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0902
# Epoch 76/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0901
# Epoch 77/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0901
# Epoch 78/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0901
# Epoch 79/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0900
# Epoch 80/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0900
# Epoch 81/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0899
# Epoch 82/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0899
# Epoch 83/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0899
# Epoch 84/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0898
# Epoch 85/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0898
# Epoch 86/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0898
# Epoch 87/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0897
# Epoch 88/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0897
# Epoch 89/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0897
# Epoch 90/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0896
# Epoch 91/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0896
# Epoch 92/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0896
# Epoch 93/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0895
# Epoch 94/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0895
# Epoch 95/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0895
# Epoch 96/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 97/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 98/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 99/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 100/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0893
# Epoch 101/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0893
# Epoch 102/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0893
# Epoch 103/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0893
# Epoch 104/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 105/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 106/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 107/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 108/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 109/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 110/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 111/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 112/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0890
# Epoch 113/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0890
# Epoch 114/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0890
# Epoch 115/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0889
# Epoch 116/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 117/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0890
# Epoch 118/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0889
# Epoch 119/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0889
# Epoch 120/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0889
# Epoch 121/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0888
# Epoch 122/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0887
# Epoch 123/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0885
# Epoch 124/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0879
# Epoch 125/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0887
# Epoch 126/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0884
# Epoch 127/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0853
# Epoch 128/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0790
# Epoch 129/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0918
# Epoch 130/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0914
# Epoch 131/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0910
# Epoch 132/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0905
# Epoch 133/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0901
# Epoch 134/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0903
# Epoch 135/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0897
# Epoch 136/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0896
# Epoch 137/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0895
# Epoch 138/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 139/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0894
# Epoch 140/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0893
# Epoch 141/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0893
# Epoch 142/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 143/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0892
# Epoch 144/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 145/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 146/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0891
# Epoch 147/1000

# %%
prediction = autoencoder.predict(X_train, verbose=0, batch_size=32)# you can now display an image to see it is reconstructed well

# %%
for i in range(3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40,20))
    ax1.imshow((prediction[i] * 255).astype(np.uint8))
    ax2.imshow(X_train[i].reshape(448, 448, 3))
    plt.show()

# %%
#autoencoder.save('autoencoder-latent-dim-800.h5')
